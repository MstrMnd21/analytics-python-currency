# %%
import pandas as pd

# %%
import numpy as nm

# %%
mDataFullUsdChfD1 = pd.read_csv ('UsdChfD1.csv')

# %%
mDataFullUsdChfD1
# Out:
#       2014.11.06  00:00  0.96445  0.97374  0.96025  0.97287  57161
# 0     2014.11.07  00:00  0.97286  0.97398  0.96508  0.96612  56569
# 1     2014.11.09  00:00  0.96369  0.96545  0.96333  0.96528   2550
# 2     2014.11.10  00:00  0.96529  0.96838  0.96158  0.96790  52460
# 3     2014.11.11  00:00  0.96789  0.97000  0.96240  0.96444  45381
# 4     2014.11.12  00:00  0.96445  0.96795  0.96219  0.96703  67538
# 5     2014.11.13  00:00  0.96703  0.96721  0.96217  0.96366  55798
# 6     2014.11.14  00:00  0.96365  0.96880  0.95730  0.95866  63666
# 7     2014.11.16  00:00  0.95859  0.95991  0.95788  0.95923   2152
# 8     2014.11.17  00:00  0.95924  0.96539  0.95517  0.96481  47761
# 9     2014.11.18  00:00  0.96475  0.96489  0.95740  0.95850  29295
# 10    2014.11.19  00:00  0.95849  0.96003  0.95295  0.95790  46385
# 11    2014.11.20  00:00  0.95789  0.96053  0.95524  0.95838  66955
# 12    2014.11.21  00:00  0.95841  0.97085  0.95624  0.96952  66246
# ...
