# %%
import pandas as pd
import numpy as np

H1_UsdChf_pd = pd.read_csv('datasets/2018-05-02-UsdChfH1.csv')
D1_UsdChf_pd = pd.read_csv('datasets/2018-05-02-UsdChfD1.csv')

# %%
# hourlyFullUsdChf_pd.drop(['Volume'], axis=1)

# df.drop(['B', 'C'], axis=1)
# df.drop(columns=['B', 'C'])

# H1_UsdChf_pd.drop(columns='Volume')
# H1_UsdChf_pd.drop('Close', axis=1)

# H1_UsdChf_pd.drop(['Volume'], axis = 1, inplace = True)

# H1_UsdChf_pd.loc[:, :'1573']


H1_UsdChf_Reshaped01_pd = H1_UsdChf_pd.drop(H1_UsdChf_pd.columns[[1, 4]], axis=1, inplace=False)
H1_UsdChf_Reshaped01_pd
# Out:
#              Time     High      Low   Volume
# 2017.11.08  01:00  0.99928  0.99862     1573
# 2017.11.08  02:00  0.99903  0.99849     1496
# 2017.11.08  03:00  0.99892  0.99855     1158
# 2017.11.08  04:00  0.99881  0.99839      707
# 2017.11.08  05:00  0.99878  0.99839      913
# 2017.11.08  06:00  0.99965  0.99869     1504
# 2017.11.08  07:00  0.99941  0.99835     1756
# 2017.11.08  08:00  0.99931  0.99829     2269
# 2017.11.08  09:00  0.99918  0.99835     1672
# 2017.11.08  10:00  0.99910  0.99830     1744
# 2017.11.08  11:00  0.99889  0.99814     1661
# 2017.11.08  12:00  0.99952  0.99854     2000
# 2017.11.08  13:00  1.00019  0.99866     2283
# 2017.11.08  14:00  1.00035  0.99937     2366
# 2017.11.08  15:00  1.00017  0.99909     2729
# 2017.11.08  16:00  1.00056  0.99875     2348
# 2017.11.08  17:00  1.00025  0.99929     1432
# 2017.11.08  18:00  1.00039  0.99955     1432
# 2017.11.08  19:00  1.00050  0.99979     1410
# 2017.11.08  20:00  1.00015  0.99980     1918
# ...
