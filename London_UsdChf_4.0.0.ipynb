# %%
## NOSTRADAMUS ASIAN-LONDON OVERLAP

# %%
import pandas as pd
import numpy as np

# %%
## PREPROCESS THE DATA
UsdJpyH1_pd = pd.read_csv('datasets/2018-08-17-UsdChfH1_raw.csv')
UsdJpyH1_pd

## Rename Columns to: Time, Open, High, Low, Close, Volume
UsdJpyH1_pd.columns = ['Date', 'Time', 'Open','High','Low','Close', 'Volume']
UsdJpyH1_zero = UsdJpyH1_pd

## Set Index to Date for Accuracy
UsdJpyH1_date = UsdJpyH1_zero.set_index('Date')

# %%
# Creating the "TIME" table

T00UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '00:00')]
T01UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '01:00')]
T02UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '02:00')]
T03UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '03:00')]
T04UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '04:00')]
T05UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '05:00')]
T06UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '06:00')]
T07UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '07:00')]
T08UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '08:00')]
T09UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '09:00')]
T10UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '10:00')]
T11UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '11:00')]
T12UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '12:00')]
T13UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '13:00')]
T14UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '14:00')]
T15UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '15:00')]
T16UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '16:00')]
T17UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '17:00')]
T18UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '18:00')]
T19UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '19:00')]
T20UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '20:00')]
T21UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '21:00')]
T22UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '22:00')]
T23UsdJpy_date = UsdJpyH1_date [(UsdJpyH1_date ['Time'] == '23:00')]

# %%
# Reshaping table to horizontal, with date as index

T00UsdJpy_date.columns = ['T00', 'O00','H00','L00','C00','Vol']
T01UsdJpy_date.columns = ['T01', 'O01','H01','L01','C01','Vol']
T02UsdJpy_date.columns = ['T02', 'O02','H02','L02','C02','Vol']
T03UsdJpy_date.columns = ['T03', 'O03','H03','L03','C03','Vol']
T04UsdJpy_date.columns = ['T04', 'O04','H04','L04','C04','Vol']
T05UsdJpy_date.columns = ['T05', 'O05','H05','L05','C05','Vol']
T06UsdJpy_date.columns = ['T06', 'O06','H06','L06','C06','Vol']
T07UsdJpy_date.columns = ['T07', 'O07','H07','L07','C07','Vol']
T08UsdJpy_date.columns = ['T08', 'O08','H08','L08','C08','Vol']
T09UsdJpy_date.columns = ['T09', 'O09','H09','L09','C09','Vol']
T10UsdJpy_date.columns = ['T10', 'O10','H10','L10','C10','Vol']
T11UsdJpy_date.columns = ['T11', 'O11','H11','L11','C11','Vol']
T12UsdJpy_date.columns = ['T12', 'O12','H12','L12','C12','Vol']
T13UsdJpy_date.columns = ['T13', 'O13','H13','L13','C13','Vol']
T14UsdJpy_date.columns = ['T14', 'O14','H14','L14','C14','Vol']
T15UsdJpy_date.columns = ['T15', 'O15','H15','L15','C15','Vol']
T16UsdJpy_date.columns = ['T16', 'O16','H16','L16','C16','Vol']
T17UsdJpy_date.columns = ['T17', 'O17','H17','L17','C17','Vol']
T18UsdJpy_date.columns = ['T18', 'O18','H18','L18','C18','Vol']
T19UsdJpy_date.columns = ['T19', 'O19','H19','L19','C19','Vol']
T20UsdJpy_date.columns = ['T20', 'O20','H20','L20','C20','Vol']
T21UsdJpy_date.columns = ['T21', 'O21','H21','L21','C21','Vol']
T22UsdJpy_date.columns = ['T22', 'O22','H22','L22','C22','Vol']
T23UsdJpy_date.columns = ['T23', 'O23','H23','L23','C23','Vol']

Table_Horizontal_date = pd.concat([T00UsdJpy_date, T01UsdJpy_date, T02UsdJpy_date, T03UsdJpy_date, T04UsdJpy_date, T05UsdJpy_date, T06UsdJpy_date, T07UsdJpy_date, T08UsdJpy_date, T09UsdJpy_date, T10UsdJpy_date, T11UsdJpy_date, T12UsdJpy_date, T13UsdJpy_date, T14UsdJpy_date, T15UsdJpy_date, T16UsdJpy_date, T17UsdJpy_date, T18UsdJpy_date, T19UsdJpy_date, T20UsdJpy_date, T21UsdJpy_date, T22UsdJpy_date, T23UsdJpy_date], axis=1)
Table_Horizontal_date
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#               T00      O00      H00      L00      C00     Vol    T01      O01  \
# 2015.01.07    NaN      NaN      NaN      NaN      NaN     NaN    NaN      NaN
# 2015.01.08  00:00  1.01432  1.01482  1.01415  1.01478  1375.0  01:00  1.01478
# 2015.01.09  00:00  1.01833  1.01893  1.01817  1.01867  1454.0  01:00  1.01867
# 2015.01.12  00:00  1.01398  1.01399  1.01178  1.01194  1420.0  01:00  1.01195
# 2015.01.13  00:00  1.01490  1.01528  1.01466  1.01525  1036.0  01:00  1.01527
# 2015.01.14  00:00  1.02005  1.02050  1.01964  1.01987   893.0  01:00  1.01978
# 2015.01.15  00:00  1.01860  1.01898  1.01828  1.01863   971.0  01:00  1.01863
# ...

# %%
# PREMONITION by ANALYTICS
# Create table for entry direction decisions
# Price change from Open 09 to Close 11

EntryDirection = Table_Horizontal_date['C11'] - Table_Horizontal_date['O09']
EntryDirection = pd.DataFrame (EntryDirection, columns = ['CALC'])
EntryDirection['POS'] = 'Default'
EntryDirection['POS'][EntryDirection['CALC'] > 0] = 'Long'
EntryDirection['POS'][EntryDirection['CALC'] < 0] = 'Short'

EntryDirection_date = EntryDirection
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# Calculate HIghs and Lows for 12:00 to 18:00

High_12TO18 = Table_Horizontal_date [['H12','H13','H14', 'H15', 'H16', 'H17', 'H18']]
High_12TO18['H1218'] = High_12TO18.max(axis=1)

Low_12TO18 = Table_Horizontal_date [['L12','L13','L14', 'L15', 'L16', 'L17', 'L18']]
Low_12TO18['L1218'] = Low_12TO18.min(axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# Create table for Closing 03:00
UsdJpyC11 = T11UsdJpy_date[['C11']]
UsdJpyO09 = T09UsdJpy_date[['O09']]

# %%
# Concatenate the tables
Table_HighLowClosePosition = pd.concat([UsdJpyO09, High_12TO18, Low_12TO18, UsdJpyC11, EntryDirection_date], axis=1)
Table_HighLowClosePosition
# Cleanup
# Table_HighLowClosePosition = Table_HighLowClosePosition[['H0410', 'L0410','C03', 'POS']]
# Table_HighLowClosePosition
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#                 O09      H12      H13      H14      H15      H16      H17  \
# 2015.01.07  1.01202  1.01411  1.01609  1.01599  1.01613  1.01699  1.01754
# 2015.01.08  1.01608  1.02092  1.02096  1.02166  1.02106  1.01947  1.02006
# 2015.01.09  1.01849  1.01723  1.01701  1.01693  1.02093  1.02003  1.01915
# 2015.01.12  1.01292  1.01834  1.01871  1.01894  1.01862  1.01683  1.01629
# 2015.01.13  1.01522  1.01862  1.01888  1.01981  1.02059  1.02146  1.02175
# 2015.01.14  1.01894  1.02306  1.02313  1.02262  1.02158  1.01874  1.02014
# 2015.01.15  1.02010  0.90475  0.88943  0.88191  0.88267  0.88768  0.91302
# ...

# %%
# Calculate Success Rate

LongPosition = Table_HighLowClosePosition ['H1218'] - Table_HighLowClosePosition ['C11']
LongPosition = pd.DataFrame (LongPosition, columns = ['PIP LONG'])

ShortPosition = Table_HighLowClosePosition ['C11'] - Table_HighLowClosePosition ['L1218']
ShortPosition = pd.DataFrame (ShortPosition, columns = ['PIP SHORT'])

# %%
Table_HighLowClosePosition = pd.concat([Table_HighLowClosePosition, LongPosition, ShortPosition], axis=1)
Table_HighLowClosePosition
# Out:
#                 O09      H12      H13      H14      H15      H16      H17  \
# 2015.01.07  1.01202  1.01411  1.01609  1.01599  1.01613  1.01699  1.01754
# 2015.01.08  1.01608  1.02092  1.02096  1.02166  1.02106  1.01947  1.02006
# 2015.01.09  1.01849  1.01723  1.01701  1.01693  1.02093  1.02003  1.01915
# 2015.01.12  1.01292  1.01834  1.01871  1.01894  1.01862  1.01683  1.01629
# 2015.01.13  1.01522  1.01862  1.01888  1.01981  1.02059  1.02146  1.02175
# 2015.01.14  1.01894  1.02306  1.02313  1.02262  1.02158  1.01874  1.02014
# 2015.01.15  1.02010  0.90475  0.88943  0.88191  0.88267  0.88768  0.91302
# 2015.01.16  0.87574  0.87950  0.87873  0.87655  0.87704  0.87394  0.86184
# 2015.01.19  0.86807  0.86820  0.87232  0.87486  0.87465  0.87262  0.87678
# 2015.01.20  0.88185  0.87626  0.87615  0.87484  0.87241  0.87392  0.87753
# 2015.01.21  0.87105  0.86687  0.86618  0.86658  0.86480  0.85895  0.86584
# 2015.01.22  0.86014  0.85988  0.85785  0.85641  0.86083  0.86294  0.87091
# ...

# %%
# Capture all Long and Short Positions

SummaryLongPosition = Table_HighLowClosePosition[(Table_HighLowClosePosition['POS'] == 'Long')]
SummaryShortPosition = Table_HighLowClosePosition[(Table_HighLowClosePosition['POS'] == 'Short')]

# %%
# For long position result
LongPosSubResult = np.where (SummaryLongPosition ['PIP LONG'] > 0.0015, 'Success', 'Fail')
LongPosSubResult = pd.DataFrame (LongPosSubResult, columns = ['LONG RESULT'])
LongPosSubResult

# Isolate BuyPosSubResult_pd
LongPosSubResult_x = LongPosSubResult

# Convert To Numpy 
LongPosSubResult_np = LongPosSubResult_x.values

# Count Contents
countTotalResultForLong = len(LongPosSubResult_np)
countSuccessResultLong = (LongPosSubResult_np == 'Success').sum() 

WinRateForLongPos = countSuccessResultLong / countTotalResultForLong
WinRateForLongPos
# Out:
# 0.6816239316239316

# %%
ShortPosSubResult = np.where (SummaryShortPosition ['PIP SHORT'] > 0.0015, 'Success', 'Fail')
ShortPosSubResult = pd.DataFrame (ShortPosSubResult, columns = ['SHORT RESULT'])
ShortPosSubResult  

# Isolate SellPosSubResult_pd
ShortPosSubResult_x = ShortPosSubResult

# Convert To Numpy
ShortPosSubResult_np = ShortPosSubResult_x.values

# Count Contents
countTotalResultForShort = len(ShortPosSubResult_np)
countSuccessResultShort = (ShortPosSubResult_np == 'Success').sum() 

WinRateForShortPos = countSuccessResultShort / countTotalResultForShort
WinRateForShortPos
# Out:
# 0.6145610278372591
