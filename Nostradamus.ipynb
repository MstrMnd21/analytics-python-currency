# %%
# Nostradamus One: NTS Framework for all pairs.
import pandas as pd
import numpy as np

# %%
# Attach all dataset and convert to dataframe
hourlyFullUsdChf_pd = pd.read_csv('UsdChfH1.csv')
# // dailyFullUsdChf_pd = pd.read_csv('UsdChfD1NoonTime.csv')                            
# // hourlySniffHighUsdChf_pd = pd.read_csv('UsdChfH1NoonTimeForSniffingHigh.csv')

# RESHAPE HOURLY CHARTS

# Noon Time Range is 21:00 to 04:00 (6am to 1pm Philippine Time). Create a dataframe for 21:00 and 14:00
mDataTime2100_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '21:00')]
mDataTime1400_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '14:00')] 

mDataTime1500_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '15:00')]
mDataTime1600_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '16:00')]
mDataTime1700_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '17:00')]
mDataTime1800_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '18:00')]
mDataTime1900_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '19:00')]
mDataTime2000_pd = hourlyFullUsdChf_pd [(hourlyFullUsdChf_pd['Time'] == '20:00')]

# Delete Columns
mDataTime1400_pd = mDataTime1400_pd.drop(mDataTime1400_pd.columns[[5]], axis=1)
mDataTime2100_pd = mDataTime2100_pd.drop(mDataTime2100_pd.columns[[5]], axis=1)

mDataTime1500_pd = mDataTime1500_pd.drop(mDataTime1500_pd.columns[[5]], axis=1)
mDataTime1600_pd = mDataTime1600_pd.drop(mDataTime1600_pd.columns[[5]], axis=1)
mDataTime1700_pd = mDataTime1700_pd.drop(mDataTime1700_pd.columns[[5]], axis=1)
mDataTime1800_pd = mDataTime1800_pd.drop(mDataTime1800_pd.columns[[5]], axis=1)
mDataTime1900_pd = mDataTime1900_pd.drop(mDataTime1900_pd.columns[[5]], axis=1)
mDataTime2000_pd = mDataTime2000_pd.drop(mDataTime2000_pd.columns[[5]], axis=1)

# Change Column Names
mDataTime1400_pd.columns = ['T14', 'O14','H14','L14','C14']
mDataTime2100_pd.columns = ['T21', 'O21','H21','L21','C21']

mDataTime1500_pd.columns = ['T15', 'O15','H15','L15','C15']
mDataTime1600_pd.columns = ['T16', 'O16','H16','L16','C16']
mDataTime1700_pd.columns = ['T17', 'O17','H17','L17','C17']
mDataTime1800_pd.columns = ['T18', 'O18','H18','L18','C18']
mDataTime1900_pd.columns = ['T19', 'O19','H19','L19','C19']
mDataTime2000_pd.columns = ['T20', 'O20','H20','L20','C20']

# Concatenate Closing 21 and 14
mDataTime21To14To20_pd = pd.concat([mDataTime2100_pd, mDataTime1400_pd, mDataTime1500_pd, mDataTime1600_pd, mDataTime1700_pd, mDataTime1800_pd, mDataTime1900_pd, mDataTime2000_pd], axis=1)

# CREATE CHART FOR ALGORITHM RESULTS

# Chart for High Low from 15:00 to 20:00 
# Chart for

# %%
mDataTime21To14To20_pd
# Out:
#               T21      O21      H21      L21      C21    T14      O14  \
# 2017.11.08  21:00  0.99990  1.00031  0.99945  0.99996  14:00  1.00010
# 2017.11.09  21:00  0.99416  0.99434  0.99359  0.99359  14:00  0.99882
# 2017.11.10  21:00  0.99571  0.99605  0.99519  0.99572  14:00  0.99555
# 2017.11.12  21:00  0.99637  0.99644  0.99547  0.99575    NaN      NaN
# 2017.11.13  21:00  0.99592  0.99620  0.99589  0.99611  14:00  0.99411
# 2017.11.14  21:00  0.98946  0.98977  0.98908  0.98924  14:00  0.99174
# 2017.11.15  21:00  0.98806  0.98853  0.98779  0.98822  14:00  0.98511
# 2017.11.16  21:00  0.99391  0.99423  0.99338  0.99388  14:00  0.99171
# 2017.11.17  21:00  0.98847  0.98929  0.98823  0.98825  14:00  0.99222
# 2017.11.19  21:00  0.98842  0.98881  0.98842  0.98872    NaN      NaN
# 2017.11.20  21:00  0.99359  0.99360  0.99294  0.99330  14:00  0.99154
# 2017.11.21  21:00  0.99123  0.99160  0.99098  0.99131  14:00  0.99246
# 2017.11.22  21:00  0.98187  0.98200  0.98139  0.98144  14:00  0.98771
# 2017.11.23  21:00  0.98105  0.98190  0.98074  0.98166  14:00  0.98090
# 2017.11.24  21:00  0.97931  0.97972  0.97852  0.97929  14:00  0.98023
# 2017.11.26  21:00  0.97849  0.97976  0.97813  0.97917    NaN      NaN
# 2017.11.27  21:00  0.98156  0.98188  0.98107  0.98135  14:00  0.97973
# 2017.11.28  21:00  0.98436  0.98436  0.98317  0.98381  14:00  0.98218
# 2017.11.29  21:00  0.98414  0.98450  0.98380  0.98439  14:00  0.98632
# 2017.11.30  21:00  0.98361  0.98364  0.98282  0.98338  14:00  0.98633
# 2017.12.01  21:00  0.97647  0.97663  0.97534  0.97561  14:00  0.98620
# 2017.12.03  21:00  0.98150  0.98152  0.98085  0.98134    NaN      NaN
# 2017.12.04  21:00  0.98539  0.98552  0.98467  0.98476  14:00  0.98389
# 2017.12.05  21:00  0.98736  0.98759  0.98693  0.98719  14:00  0.98519
# 2017.12.06  21:00  0.98980  0.98999  0.98953  0.98972  14:00  0.98854
# 2017.12.07  21:00  0.99421  0.99457  0.99414  0.99421  14:00  0.99116
# 2017.12.08  21:00  0.99284  0.99291  0.99224  0.99254  14:00  0.99435
# 2017.12.10  21:00  0.99375  0.99403  0.99368  0.99376    NaN      NaN
# 2017.12.11  21:00  0.99174  0.99203  0.99161  0.99170  14:00  0.99140
# 2017.12.12  21:00  0.99115  0.99142  0.99085  0.99137  14:00  0.99214
# ...           ...      ...      ...      ...      ...    ...      ...
# 2018.02.06  21:00  0.93705  0.93743  0.93539  0.93584  14:00  0.93824
# 2018.02.07  21:00  0.94368  0.94412  0.94241  0.94370  14:00  0.94063
# 2018.02.08  21:00  0.93599  0.93635  0.93571  0.93591  14:00  0.94065
# 2018.02.09  21:00  0.93998  0.93998  0.93913  0.93934  14:00  0.93733
# 2018.02.11  21:00  0.93955  0.93968  0.93955  0.93956    NaN      NaN
# 2018.02.12  21:00  0.93903  0.93951  0.93887  0.93899  14:00  0.93880
# 2018.02.13  21:00  0.93506  0.93514  0.93467  0.93467  14:00  0.93413
# 2018.02.14  21:00  0.92898  0.92958  0.92889  0.92928  14:00  0.93572
# 2018.02.15  21:00  0.92149  0.92222  0.92145  0.92188  14:00  0.92487
# 2018.02.16  21:00  0.92763  0.92763  0.92685  0.92732  14:00  0.92477
# 2018.02.18  21:00  0.92724  0.92735  0.92724  0.92735    NaN      NaN
# 2018.02.19  21:00  0.92878  0.92905  0.92839  0.92899  14:00  0.93126
# 2018.02.20  21:00  0.93576  0.93630  0.93576  0.93602  14:00  0.93601
# 2018.02.21  21:00  0.93828  0.93894  0.93765  0.93863  14:00  0.93700
# 2018.02.22  21:00  0.93292  0.93317  0.93265  0.93273  14:00  0.93556
# 2018.02.23  21:00  0.93667  0.93702  0.93585  0.93595  14:00  0.93592
# 2018.02.25  21:00  0.93620  0.93698  0.93548  0.93698    NaN      NaN
# 2018.02.26  21:00  0.93806  0.93833  0.93759  0.93777  14:00  0.93736
# 2018.02.27  21:00  0.93902  0.93930  0.93880  0.93884  14:00  0.93891
# 2018.02.28  21:00  0.94432  0.94457  0.94394  0.94442  14:00  0.94277
# 2018.03.01  21:00  0.94225  0.94225  0.94151  0.94161  14:00  0.94619
# 2018.03.02  21:00  0.93714  0.93782  0.93700  0.93708  14:00  0.93532
# 2018.03.04  21:00  0.93463  0.93693  0.93455  0.93624    NaN      NaN
# 2018.03.05  21:00  0.94010  0.94028  0.93969  0.93972  14:00  0.93808
# 2018.03.06  21:00  0.94083  0.94088  0.93997  0.94055  14:00  0.93609
# 2018.03.07  21:00  0.94304  0.94345  0.94271  0.94335  14:00  0.94087
# 2018.03.08  21:00  0.95093  0.95116  0.95056  0.95091  14:00  0.94656
# 2018.03.09  21:00  0.95104  0.95143  0.95103  0.95116  14:00  0.95030
# 2018.03.11  21:00  0.95033  0.95120  0.94968  0.95102    NaN      NaN
# 2018.03.12    NaN      NaN      NaN      NaN      NaN  14:00  0.94872
#
#                 H14      L14      C14   ...       T19      O19      H19  \
# 2017.11.08  1.00035  0.99937  0.99972   ...     19:00  1.00010  1.00050
# 2017.11.09  0.99950  0.99609  0.99632   ...     19:00  0.99311  0.99400
# 2017.11.10  0.99569  0.99428  0.99444   ...     19:00  0.99595  0.99624
# 2017.11.12      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2017.11.13  0.99586  0.99372  0.99584   ...     19:00  0.99578  0.99588
# 2017.11.14  0.99249  0.99099  0.99189   ...     19:00  0.98848  0.98957
# 2017.11.15  0.98730  0.98508  0.98552   ...     19:00  0.98783  0.98897
# 2017.11.16  0.99231  0.99005  0.99073   ...     19:00  0.99343  0.99427
# 2017.11.17  0.99223  0.98964  0.99037   ...     19:00  0.98852  0.98887
# 2017.11.19      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2017.11.20  0.99241  0.99111  0.99198   ...     19:00  0.99276  0.99353
# 2017.11.21  0.99269  0.98984  0.99083   ...     19:00  0.99137  0.99209
# 2017.11.22  0.98776  0.98587  0.98594   ...     19:00  0.98343  0.98365
# 2017.11.23  0.98136  0.98075  0.98095   ...     19:00  0.98145  0.98194
# 2017.11.24  0.98058  0.97897  0.97932   ...     19:00  0.97941  0.97989
# 2017.11.26      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2017.11.27  0.98079  0.97931  0.98022   ...     19:00  0.98147  0.98158
# 2017.11.28  0.98368  0.98189  0.98368   ...     19:00  0.98264  0.98519
# 2017.11.29  0.98690  0.98469  0.98564   ...     19:00  0.98484  0.98484
# 2017.11.30  0.98651  0.98343  0.98362   ...     19:00  0.98288  0.98452
# 2017.12.01  0.98658  0.98502  0.98658   ...     19:00  0.97708  0.97765
# 2017.12.03      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2017.12.04  0.98540  0.98389  0.98486   ...     19:00  0.98613  0.98620
# 2017.12.05  0.98740  0.98516  0.98708   ...     19:00  0.98826  0.98840
# 2017.12.06  0.98988  0.98844  0.98971   ...     19:00  0.99018  0.99041
# 2017.12.07  0.99217  0.99114  0.99160   ...     19:00  0.99248  0.99448
# 2017.12.08  0.99527  0.99352  0.99403   ...     19:00  0.99251  0.99306
# 2017.12.10      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2017.12.11  0.99194  0.99085  0.99105   ...     19:00  0.99058  0.99142
# 2017.12.12  0.99338  0.99186  0.99268   ...     19:00  0.99192  0.99239
# ...             ...      ...      ...   ...       ...      ...      ...
# 2018.02.06  0.93971  0.93693  0.93810   ...     19:00  0.93474  0.93608
# 2018.02.07  0.94145  0.94019  0.94079   ...     19:00  0.94370  0.94385
# 2018.02.08  0.94088  0.93889  0.94007   ...     19:00  0.93682  0.93736
# 2018.02.09  0.93870  0.93733  0.93850   ...     19:00  0.93806  0.94036
# 2018.02.11      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2018.02.12  0.93936  0.93809  0.93861   ...     19:00  0.93849  0.93910
# 2018.02.13  0.93484  0.93331  0.93341   ...     19:00  0.93437  0.93461
# 2018.02.14  0.93734  0.93489  0.93638   ...     19:00  0.92999  0.93078
# 2018.02.15  0.92576  0.92272  0.92293   ...     19:00  0.92314  0.92349
# 2018.02.16  0.92622  0.92435  0.92535   ...     19:00  0.92790  0.92868
# 2018.02.18      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2018.02.19  0.93191  0.93067  0.93131   ...     19:00  0.92882  0.92906
# 2018.02.20  0.93623  0.93303  0.93406   ...     19:00  0.93603  0.93644
# 2018.02.21  0.93729  0.93565  0.93696   ...     19:00  0.93684  0.93869
# 2018.02.22  0.93620  0.93345  0.93406   ...     19:00  0.93380  0.93388
# 2018.02.23  0.93733  0.93522  0.93612   ...     19:00  0.93611  0.93655
# 2018.02.25      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2018.02.26  0.93839  0.93673  0.93709   ...     19:00  0.93758  0.93807
# 2018.02.27  0.93988  0.93808  0.93930   ...     19:00  0.93871  0.93915
# 2018.02.28  0.94421  0.94209  0.94408   ...     19:00  0.94378  0.94419
# 2018.03.01  0.94824  0.94596  0.94667   ...     19:00  0.94688  0.94698
# 2018.03.02  0.93668  0.93494  0.93596   ...     19:00  0.93745  0.93793
# 2018.03.04      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2018.03.05  0.93897  0.93761  0.93778   ...     19:00  0.94004  0.94054
# 2018.03.06  0.93876  0.93609  0.93825   ...     19:00  0.93958  0.94084
# 2018.03.07  0.94266  0.94051  0.94213   ...     19:00  0.94336  0.94412
# 2018.03.08  0.94760  0.94576  0.94760   ...     19:00  0.95080  0.95195
# 2018.03.09  0.95101  0.94945  0.95051   ...     19:00  0.95088  0.95115
# 2018.03.11      NaN      NaN      NaN   ...       NaN      NaN      NaN
# 2018.03.12  0.94986  0.94782  0.94788   ...       NaN      NaN      NaN
#
#                 L19      C19    T20      O20      H20      L20      C20
# 2017.11.08  0.99979  1.00014  20:00  1.00012  1.00015  0.99980  0.99989
# 2017.11.09  0.99294  0.99304  20:00  0.99302  0.99424  0.99291  0.99417
# 2017.11.10  0.99506  0.99574  20:00  0.99573  0.99589  0.99536  0.99572
# 2017.11.12      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2017.11.13  0.99531  0.99565  20:00  0.99565  0.99626  0.99564  0.99591
# 2017.11.14  0.98816  0.98946  20:00  0.98947  0.98994  0.98928  0.98946
# 2017.11.15  0.98753  0.98859  20:00  0.98859  0.98873  0.98765  0.98807
# 2017.11.16  0.99343  0.99362  20:00  0.99361  0.99446  0.99361  0.99391
# 2017.11.17  0.98840  0.98852  20:00  0.98851  0.98859  0.98753  0.98849
# 2017.11.19      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2017.11.20  0.99255  0.99314  20:00  0.99318  0.99364  0.99262  0.99359
# 2017.11.21  0.99105  0.99184  20:00  0.99184  0.99202  0.99114  0.99124
# 2017.11.22  0.98119  0.98148  20:00  0.98147  0.98249  0.98129  0.98188
# 2017.11.23  0.98097  0.98139  20:00  0.98137  0.98209  0.98071  0.98114
# 2017.11.24  0.97892  0.97975  20:00  0.97976  0.97995  0.97885  0.97929
# 2017.11.26      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2017.11.27  0.98093  0.98105  20:00  0.98104  0.98180  0.98103  0.98155
# 2017.11.28  0.98230  0.98440  20:00  0.98442  0.98459  0.98386  0.98435
# 2017.11.29  0.98360  0.98378  20:00  0.98377  0.98439  0.98370  0.98413
# 2017.11.30  0.98288  0.98403  20:00  0.98402  0.98456  0.98350  0.98361
# 2017.12.01  0.97544  0.97567  20:00  0.97571  0.97658  0.97565  0.97652
# 2017.12.03      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2017.12.04  0.98486  0.98574  20:00  0.98574  0.98622  0.98521  0.98538
# 2017.12.05  0.98738  0.98819  20:00  0.98819  0.98827  0.98699  0.98735
# 2017.12.06  0.98979  0.99030  20:00  0.99030  0.99038  0.98951  0.98981
# 2017.12.07  0.99245  0.99435  20:00  0.99436  0.99460  0.99377  0.99420
# 2017.12.08  0.99235  0.99277  20:00  0.99276  0.99294  0.99259  0.99285
# 2017.12.10      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2017.12.11  0.99044  0.99132  20:00  0.99131  0.99183  0.99111  0.99176
# 2017.12.12  0.99180  0.99222  20:00  0.99222  0.99223  0.99112  0.99116
# ...             ...      ...    ...      ...      ...      ...      ...
# 2018.02.06  0.93457  0.93587  20:00  0.93588  0.93710  0.93578  0.93702
# 2018.02.07  0.94228  0.94248  20:00  0.94245  0.94434  0.94245  0.94367
# 2018.02.08  0.93626  0.93647  20:00  0.93648  0.93692  0.93550  0.93598
# 2018.02.09  0.93784  0.93865  20:00  0.93862  0.94005  0.93841  0.93997
# 2018.02.11      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2018.02.12  0.93845  0.93884  20:00  0.93883  0.93910  0.93814  0.93902
# 2018.02.13  0.93390  0.93446  20:00  0.93445  0.93539  0.93403  0.93505
# 2018.02.14  0.92964  0.93065  20:00  0.93064  0.93086  0.92898  0.92899
# 2018.02.15  0.92250  0.92261  20:00  0.92261  0.92285  0.92095  0.92150
# 2018.02.16  0.92722  0.92738  20:00  0.92740  0.92823  0.92723  0.92765
# 2018.02.18      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2018.02.19  0.92879  0.92889  20:00  0.92888  0.92895  0.92830  0.92879
# 2018.02.20  0.93523  0.93581  20:00  0.93582  0.93600  0.93543  0.93574
# 2018.02.21  0.93423  0.93854  20:00  0.93855  0.93959  0.93814  0.93829
# 2018.02.22  0.93272  0.93312  20:00  0.93312  0.93357  0.93269  0.93294
# 2018.02.23  0.93594  0.93626  20:00  0.93626  0.93682  0.93555  0.93668
# 2018.02.25      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2018.02.26  0.93754  0.93787  20:00  0.93786  0.93830  0.93769  0.93806
# 2018.02.27  0.93840  0.93903  20:00  0.93903  0.93912  0.93857  0.93904
# 2018.02.28  0.94352  0.94385  20:00  0.94383  0.94455  0.94383  0.94433
# 2018.03.01  0.94204  0.94247  20:00  0.94239  0.94282  0.94095  0.94226
# 2018.03.02  0.93638  0.93679  20:00  0.93678  0.93737  0.93655  0.93714
# 2018.03.04      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2018.03.05  0.93986  0.94041  20:00  0.94039  0.94075  0.94003  0.94007
# 2018.03.06  0.93917  0.94061  20:00  0.94059  0.94117  0.94029  0.94084
# 2018.03.07  0.94309  0.94350  20:00  0.94351  0.94379  0.94291  0.94306
# 2018.03.08  0.95070  0.95149  20:00  0.95152  0.95181  0.95081  0.95089
# 2018.03.09  0.95056  0.95076  20:00  0.95077  0.95143  0.95060  0.95104
# 2018.03.11      NaN      NaN    NaN      NaN      NaN      NaN      NaN
# 2018.03.12      NaN      NaN    NaN      NaN      NaN      NaN      NaN
#
# [102 rows x 40 columns]

# %%
mDataBullBear = reshapedDataSet_pd ['Close 21'] - reshapedDataSet_pd ['Close 04']
mDataBullBear_pd = pd.DataFrame (mDataBullBear, columns = ['BlBr Calc'])
mDataBullBear_pd

# %%
# Add Column BullBear
mDataBullBearResult = np.where (mDataBullBear_pd ['BlBr Calc'] > 0, 'bull', 'bear')
mDataBullBearResult_pd = pd.DataFrame (mDataBullBearResult, columns = ['Bull or Bear'])

mDataBullBearResult_pd

# %%
mDataAnalysis = pd.concat([mDataBullBear_pd, mDataBullBearResult_pd], axis=1)
mDataAnalysis

# %%
# Pseudo Code for Column Result Calc
    # if BullBear == bull
        # dHigh - Close 04
    # else if Bull Bear = bear
        # dLow - Close 04
        
# Pseudo Code for Colume Result 
    # if BullBear >= 14.5 pips
        # return success
        
    # else if BullBear < 14.5 pips
        # return fail

# %%
# Another Option: Separate Bull and Bear Result then count if 15 pips higher then count if success or fail
# Choose bull and bear result separately
mDataBull = mDataTime21To04DailyHighBullBear_pd[(mDataTime21To04DailyHighBullBear_pd['BullBear'] == 'bull')]
mDataBear = mDataTime21To04DailyHighBullBear_pd[(mDataTime21To04DailyHighBullBear_pd['BullBear'] == 'bear')]

# %%
# creating dataframe bull and bear
mDataBull_pd = pd.DataFrame (mDataBull)
mDataBear_pd = pd.DataFrame (mDataBear)

# %%
# Add Result Column for bull DataFrame
mDataBull_pd ['ResultBull'] = mDataBull_pd ['dHigh'] - mDataBull_pd ['Close 04'] 
mDataBull_pd

# %%
# Add Result Column for bear Dataframe
mDataBear_pd ['ResultBear'] = mDataBear_pd ['Close 04'] - mDataBear_pd ['dLow'] 
mDataBear_pd

# %%
# LIST OF SYNTAX For Reference
    # Math Operations >> rShapeData1_pd ['UpOrDown'] = rShapeData1_pd ['Close'] - rShapeData1_pd ['Open'] 
    # Renaming Columns >> mDataTime0400_pd.columns = ['Time 04', 'Open 04','High 04','Low 04','Close 04','Volume 04']
    # Create Object >> data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
    #                   >> 'age': [42, 52, 36, 24, 73], 
    #                   >> 'preTestScore': [4, 24, 31, 2, 3],
    #                   >> 'postTestScore': [25, 94, 57, 62, 70]}
    #               >> df = pd.DataFrame(data, columns = ['name', 'age', 'preTestScore', 'postTestScore'])
    #               >> df
    # Make New Columns Based On Condition >> df['elderly'] = np.where(df['age']>=50, 'yes', 'no')
    # Selecting Columns >> rShapeData1_pd[(rShapeData1_pd['Day'] == 5) & (rShapeData1_pd['UpOrDown'] > 0
    
    # Daily High Low
        # mDataHighDaily_pd = dailyFullUsdChf_pd.drop(dailyFullUsdChf_pd.columns[[0, 1, 4, 5]], axis=1)
        # mDataHighDaily_pd.columns = ['DHigh', 'DLow']

    # Concatenate dataframes at vertical axis 
        # Reshaped Dataset
        # mDataTime21To14ToDHigh_pd = pd.concat([mDataTime2100_pd, mDataTime1400_pd, mDataHighDaily_pd], axis=1)
        # reshapedDataSet_pd = mDataTime21To14ToDHigh_pd
        # Notes: After reshaping the dataset, we will do dataframe analytics
